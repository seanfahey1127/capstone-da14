# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
catch = pd.read_csv("../data/Small Mesh Survey Data; Catch Table.csv")

# %%
catch
# Out:
#        region  vessel  cruise  haul  species_code      species_name  \
# 0          BS      21  198202     9         20051     Ulcina olriki
# 1          BS      31  198001   181         20051     Ulcina olriki
# 2          BS      31  198001   197         20051     Ulcina olriki
# 3          BS      31  198001   238         20051     Ulcina olriki
# 4          BS      31  198001   182         20051     Ulcina olriki
# ...       ...     ...     ...   ...           ...               ...
# 164087    GOA      14  197102    10         95000  Bryozoa unident.
# 164088    GOA      37  198802    12         95000  Bryozoa unident.
# 164089    GOA      37  198802     1         95000  Bryozoa unident.
# 164090    GOA      88  200102    15         95000  Bryozoa unident.
# 164091     BS      38  196402   246         95000  Bryozoa unident.
#
#                  common_name  weight  number_fish   gear  subsample_code  \
# 0       Arctic alligatorfish   0.045          1.0   30.0             NaN
# ...

# %%
catch['region'].value_counts()
# Out:
# region
# BS     91462
# GOA    69489
# AI      3141
# Name: count, dtype: int64

# %%
catch['species_name'].value_counts()
# Out:
# species_name
# Theragra chalcogramma        7611
# Hippoglossoides elassodon    6369
# Gadus macrocephalus          5940
# Pandalus eous (=borealis)    4771
# Atheresthes stomias          4731
#                              ...
# Oneirodes acanthias             1
# Sertularia robusta              1
# Velutina plicatilis             1
# Panomya arctica                 1
# Artediellus uncinatus           1
# Name: count, Length: 761, dtype: int64
